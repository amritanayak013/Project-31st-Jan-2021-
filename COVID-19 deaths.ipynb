# %%
import warnings
warnings.simplefilter('ignore')

# %%
import pandas as pd
df=pd.read_csv('aggregate_covid_country.csv')
df.head()
# Out:
#          Date      Country  Confirmed  Recovered  Deaths
# 0  2020-01-22  Afghanistan          0          0       0
# 1  2020-01-22      Albania          0          0       0
# 2  2020-01-22      Algeria          0          0       0
# 3  2020-01-22      Andorra          0          0       0
# 4  2020-01-22       Angola          0          0       0

# %%
df.shape
# Out:
# (23688, 5)

# %%
df.describe()
# Out:
#           Confirmed      Recovered        Deaths
# count  2.368800e+04   23688.000000  23688.000000
# mean   7.969368e+03    2581.801714    526.935030
# std    5.842109e+04   15143.101257   3992.815956
# min    0.000000e+00       0.000000      0.000000
# 25%    0.000000e+00       0.000000      0.000000
# 50%    1.800000e+01       1.000000      0.000000
# 75%    7.300000e+02     123.000000     13.000000
# max    1.680913e+06  384902.000000  98913.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23688 entries, 0 to 23687
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       23688 non-null  object
#  1   Country    23688 non-null  object
#  2   Confirmed  23688 non-null  int64
#  3   Recovered  23688 non-null  int64
#  4   Deaths     23688 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 925.4+ KB

# %%
df.isnull().sum()
# Out:
# Date         0
# Country      0
# Confirmed    0
# Recovered    0
# Deaths       0
# dtype: int64

# %%
import seaborn as sn
import numpy as np
sn.scatterplot (x="Confirmed",y="Deaths", data=df)

# %%
sn.scatterplot (x="Recovered",y="Deaths", data=df)

# %%
df.corr()
# Out:
#            Confirmed  Recovered    Deaths
# Confirmed   1.000000   0.810991  0.929718
# Recovered   0.810991   1.000000  0.778094
# Deaths      0.929718   0.778094  1.000000

# %%
import matplotlib.pyplot as plt
plt.figure (figsize=(15,7))
sn.heatmap (df.corr(),annot= True,linewidths=0.5, fmt='.2f')

# %%
df.describe()
# Out:
#           Confirmed      Recovered        Deaths
# count  2.368800e+04   23688.000000  23688.000000
# mean   7.969368e+03    2581.801714    526.935030
# std    5.842109e+04   15143.101257   3992.815956
# min    0.000000e+00       0.000000      0.000000
# 25%    0.000000e+00       0.000000      0.000000
# 50%    1.800000e+01       1.000000      0.000000
# 75%    7.300000e+02     123.000000     13.000000
# max    1.680913e+06  384902.000000  98913.000000

# %%
plt.figure(figsize=(15,12))
sn.heatmap(round (df.describe()[1:].transpose(),2),linewidth=2, annot= True, fmt='f')
plt.xticks (fontsize=18)
plt.yticks (fontsize=14)
plt.title("Variables Summary")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23688 entries, 0 to 23687
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       23688 non-null  object
#  1   Country    23688 non-null  object
#  2   Confirmed  23688 non-null  int64
#  3   Recovered  23688 non-null  int64
#  4   Deaths     23688 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 925.4+ KB

# %%
df.skew()
# Out:
# Confirmed    18.674502
# Recovered    10.662286
# Deaths       14.218167
# dtype: float64

# %%
sn.distplot(df["Confirmed"])

# %%
sn.distplot(df["Recovered"])

# %%
sn.distplot(df["Deaths"])
